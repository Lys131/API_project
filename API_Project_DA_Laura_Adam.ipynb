# %% [markdown]
# # Ticketmaster API Project

# %% [markdown]
# Using the Discovery API of the Ticketmaster website, we managed to get the information about the events of Berlin and Toulouse.
# These data were saved in a csv file.

# %%
import pandas as pd
import json
url = "~/Desktop/DATA_FT_May_2025/Week 3/data_events.csv"

#Creating a DataFrame from the csv file:
df_events = pd.read_csv(url)
df_events.head(3)
# Out:
#    Unnamed: 0                                               name  \
# 0           0              15 000 voix pour les legendes du rock
# 1           1  dirty dancing - l'ecran pop cinéma-karaoké:dir...
# 2           2  mamma mia ! - l'ecran pop cinéma-karaoké : mam...
#
#                                          description  \
# 0  en tournée à partir de 2026vivez une expérienc...
# 1  tal ticket présente : l'ecran pop cinéma-karao...
# 2  tal ticket présente : l'ecran pop cinéma-karao...
#
#                                                  url locale      timezone  \
# 0  https://www.ticketmaster.fr/fr/manifestation/1...  fr-fr  Europe/Paris
# 1  https://www.ticketmaster.fr/fr/manifestation/d...  fr-fr  Europe/Paris
# 2  https://www.ticketmaster.fr/fr/manifestation/m...  fr-fr  Europe/Paris
#
#          date      time segment  genre subgenre                      venue  \
# 0  2026-06-05  20:00:00   Music   Rock      Pop  zenith toulouse metropole
# 1  2025-06-06  20:00:00    Film  Music    Music        cinema pathe wilson
# 2  2025-09-25  20:00:00    Film  Music    Music        cinema pathe wilson
#
#        city country                           address  upcoming_events
# 0  Toulouse  France          11 avenue raymond badiou              111
# 1  Toulouse  France  3 pl. du président thomas wilson                2
# 2  Toulouse  France  3 pl. du président thomas wilson                2

# %%
# Erasing the duplicated index column:
df_events.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
# Checking the structure of the dataframe:
df_events.head(3)
# Out:
#                                                 name  \
# 0              15 000 voix pour les legendes du rock
# 1  dirty dancing - l'ecran pop cinéma-karaoké:dir...
# 2  mamma mia ! - l'ecran pop cinéma-karaoké : mam...
#
#                                          description  \
# 0  en tournée à partir de 2026vivez une expérienc...
# 1  tal ticket présente : l'ecran pop cinéma-karao...
# 2  tal ticket présente : l'ecran pop cinéma-karao...
#
#                                                  url locale      timezone  \
# 0  https://www.ticketmaster.fr/fr/manifestation/1...  fr-fr  Europe/Paris
# 1  https://www.ticketmaster.fr/fr/manifestation/d...  fr-fr  Europe/Paris
# 2  https://www.ticketmaster.fr/fr/manifestation/m...  fr-fr  Europe/Paris
#
#          date      time segment  genre subgenre                      venue  \
# 0  2026-06-05  20:00:00   Music   Rock      Pop  zenith toulouse metropole
# 1  2025-06-06  20:00:00    Film  Music    Music        cinema pathe wilson
# 2  2025-09-25  20:00:00    Film  Music    Music        cinema pathe wilson
#
#        city country                           address  upcoming_events
# 0  Toulouse  France          11 avenue raymond badiou              111
# 1  Toulouse  France  3 pl. du président thomas wilson                2
# 2  Toulouse  France  3 pl. du président thomas wilson                2

# %%
# Checking the columns of the dataframe:
df_events.columns
# Out:
# Index(['name', 'description', 'url', 'locale', 'timezone', 'date', 'time',
#        'segment', 'genre', 'subgenre', 'venue', 'city', 'country', 'address',
#        'upcoming_events'],
#       dtype='object')

# %%
# Checking the amount of unique values for each dimension:
df_events.nunique()
# Out:
# name               370
# description        122
# url                393
# locale               2
# timezone             2
# date               217
# time                17
# segment              4
# genre               20
# subgenre            29
# venue               18
# city                 2
# country              2
# address             44
# upcoming_events     23
# dtype: int64

# %%
df_events['time'].value_counts()
# Out:
# time
# 20:00:00    254
# 19:30:00     34
# 19:00:00     32
# 20:30:00     31
# 18:00:00     14
# 17:00:00      7
# 19:45:00      6
# 15:00:00      3
# 18:30:00      2
# 17:30:00      2
# 10:00:00      2
# 11:30:00      2
# 15:30:00      2
# 16:00:00      1
# 21:00:00      1
# 13:00:00      1
# 23:00:00      1
# Name: count, dtype: int64

# %%
# Verifying segment's values:
df_events["segment"].unique()
# Out:
# array(['Music', 'Film', 'Arts & Theatre', 'Miscellaneous'], dtype=object)

# %%
# Proportion of events for each segment:
df_events["segment"].value_counts()
# Out:
# segment
# Music             377
# Film               12
# Arts & Theatre     12
# Miscellaneous       1
# Name: count, dtype: int64

# %%
# Types of genre:
df_events["genre"].unique()
# Out:
# array(['Rock', 'Music', "Children's Music", 'Pop', 'Metal',
#        'Chanson Francaise', 'R&B', 'Jazz', 'Hip-Hop/Rap',
#        'Dance/Electronic', 'Undefined', 'Religious', 'World',
#        'Alternative', 'Folk', 'Spectacular', 'Classical', 'Theatre',
#        'Other', 'Family'], dtype=object)

# %%
# Number of events of each genre:
df_events["genre"].value_counts()
# Out:
# genre
# Rock                 171
# Hip-Hop/Rap           61
# Chanson Francaise     50
# Alternative           17
# Children's Music      13
# Pop                   13
# Classical             13
# Music                 12
# Dance/Electronic      12
# Metal                  9
# Undefined              8
# World                  7
# Jazz                   4
# Folk                   4
# R&B                    2
# Other                  2
# Religious              1
# Spectacular            1
# Theatre                1
# Family                 1
# Name: count, dtype: int64

# %%
# Types of subgenre:
df_events["subgenre"].unique()
# Out:
# array(['Pop', 'Music', "Children's Music", 'Adult Contemporary', 'Metal',
#        'Chanson Francaise', 'R&B', 'Jazz', 'Hip-Hop/Rap',
#        'Dance/Electronic', 'Undefined', 'Gospel', 'World', 'Hard Rock',
#        'Heavy Metal', 'Alternative Rock', 'Alternative', 'Indie Rock',
#        'Indie Pop', 'Pop Rock', 'Urban', 'Folk', 'Spectacular',
#        'Classical/Vocal', 'Miscellaneous', 'Folk Rock', 'Soul', 'Other',
#        'Europe'], dtype=object)

# %%
# Number of events of each subgenre:
df_events["subgenre"].value_counts()
# Out:
# subgenre
# Pop                   165
# Hip-Hop/Rap            60
# Chanson Francaise      50
# Alternative Rock       15
# Children's Music       13
# Classical/Vocal        13
# Dance/Electronic       12
# Music                  12
# Hard Rock              11
# Metal                   8
# Undefined               8
# Indie Pop               6
# Europe                  6
# Jazz                    4
# Folk                    3
# Other                   3
# World                   1
# Gospel                  1
# Alternative             1
# Indie Rock              1
# R&B                     1
# Pop Rock                1
# Urban                   1
# Spectacular             1
# Adult Contemporary      1
# Miscellaneous           1
# Folk Rock               1
# Soul                    1
# Heavy Metal             1
# Name: count, dtype: int64

# %%
# Number of venues:
df_events["venue"].nunique()
# Out:
# 18

# %%
# Number of events for each venue:
df_events["venue"].value_counts()
# Out:
# venue
# uber arena                         88
# zenith toulouse metropole          62
# casino - barriere                  26
# uber eats music hall               18
# la cabane                          14
# le rex de toulouse                 14
# tempodrom                           6
# le metronum                         5
# prairie des filtres                 5
# columbia theater                    5
# lark                                2
# comedie de la roseraie              2
# cinema pathe wilson                 2
# halle aux grains                    2
# halle de la machine                 1
# festsaal kreuzberg - biergarten     1
# dstrkt                              1
# flughafen tempelhof                 1
# Name: count, dtype: int64

# %%
# df_events.loc[df_events["venue"] == "zenith toulouse metropole"]

# %% [markdown]
# ## **Events per city**

# %%
import seaborn as sns

# %% [markdown]
# *Plotting a graph to visualize the count of events at both cities:*

# %%
sns.countplot(x='city', data=df_events, hue='city', palette='bright')
# Out:
# <Axes: xlabel='city', ylabel='count'>

# %% [markdown]
# *Let's check how the amount of events for each city and its populations relate:*

# %% [markdown]
# Berlin Population: 3.432 million (Dec 31, 2023)
#
# Toulouse Population: 511 684 (Dec 19, 2024)

# %%
# Defining population variables:
berlin_pop = 3432000
toulouse_pop = 511684

#Number of events for each city:
berlin_events = 260
toulouse_events = 133

#Population/event rate for each city:
pop_event_rate_toulouse = round((toulouse_pop/toulouse_events), None)
pop_event_rate_berlin = round((berlin_pop/berlin_events), None)

# %%
#Transforming the data into a dataframe:
pop_event_rates = [pop_event_rate_toulouse, pop_event_rate_berlin]
df_pop_event = pd.DataFrame(pop_event_rates, index=["Toulouse", "Berlin"], columns=["population_event_rate"])
df_pop_event
# Out:
#           population_event_rate
# Toulouse                   3847
# Berlin                    13200

# %% [markdown]
# *Now let's see how the events are divided regarding their start time:*

# %%
import matplotlib.pyplot as plt
events_times = sns.countplot(x='time', data=df_events, hue='time', palette='bright', order=df_events['time'].value_counts().index)
events_times.tick_params(axis='x', labelrotation = 45)
plt.title('Hours of Events in Berlin and Toulouse', fontsize=16)
plt.xlabel('Event Time', fontsize=14)
plt.ylabel('Number of Events', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend('',frameon=False)
plt.show()

# %% [markdown]
# *And now regarding the venues of the events:*

# %%
events_venues = sns.countplot(x="venue", data=df_events, hue='venue', palette='bright', order=df_events['venue'].value_counts().index)
plt.title('Venues of Events in Berlin and Toulouse', fontsize=16)
plt.xlabel('Venues', fontsize=14)
plt.ylabel('Number of Events', fontsize=14)
plt.xticks('')
plt.yticks(fontsize=10)
handles, labels = plt.gca().get_legend_handles_labels()

# specify order
order = [11, 0, 4, 12, 3, 5, 13, 2, 8, 10, 14, 9, 1, 6, 7, 15, 16, 17]

# pass handle & labels lists along with order as below
plt.legend([handles[i] for i in order], [labels[i] for i in order])
plt.legend(fontsize=8)

plt.show()

# %% [markdown]
# *Selecting the 6 venues with more upcoming events:*

# %%
venue_list= ["uber arena","zenith toulouse metropole", "casino - barriere", "uber eats music hall","la cabane", "le rex de toulouse"]
event_venue_list= [87, 62, 26, 18,14, 14]
df_venues = pd.DataFrame(data=event_venue_list, index = venue_list)

df_venues.reset_index(inplace=True)
df_venues.columns= ["venue", "events"]
df_venues
# Out:
#                        venue  events
# 0                 uber arena      87
# 1  zenith toulouse metropole      62
# 2          casino - barriere      26
# 3       uber eats music hall      18
# 4                  la cabane      14
# 5         le rex de toulouse      14

# %% [markdown]
# *Verifying the capacities for each venue and creating a dataframe:*

# %%
capacities = [17000, 11000, 1200, 4350, 750, 400]
capacities_series = pd.Series(data=capacities)
df_venues_2 = pd.concat([df_venues, capacities_series], axis=1)
df_venues_2.columns= ["venue", "events", "venue_capacity"]
df_venues_2
# Out:
#                        venue  events  venue_capacity
# 0                 uber arena      87           17000
# 1  zenith toulouse metropole      62           11000
# 2          casino - barriere      26            1200
# 3       uber eats music hall      18            4350
# 4                  la cabane      14             750
# 5         le rex de toulouse      14             400

# %%
df_events
# Out:
#                                                   name  \
# 0                15 000 voix pour les legendes du rock
# 1    dirty dancing - l'ecran pop cinéma-karaoké:dir...
# 2    mamma mia ! - l'ecran pop cinéma-karaoké : mam...
# 3                                        the silencers
# 4                                                puggy
# ..                                                 ...
# 397      kontra k | box seat in the ticketmaster suite
# 398      kontra k | box seat in the ticketmaster suite
# 399      playboi carti | premium seated ticket package
# 400  playboi carti | box seat in the ticketmaster s...
# 401  post malone presents: the big ass world tour |...
#
#                                            description  \
# 0    en tournée à partir de 2026vivez une expérienc...
# 1    tal ticket présente : l'ecran pop cinéma-karao...
# 2    tal ticket présente : l'ecran pop cinéma-karao...
# 3    the silencers en concert à toulouse le 17 octo...
# 4    pour des raisons indépendantes de notre volont...
# ..                                                 ...
# 397                                                NaN
# 398                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
#
#                                                    url locale       timezone  \
# 0    https://www.ticketmaster.fr/fr/manifestation/1...  fr-fr   Europe/Paris
# 1    https://www.ticketmaster.fr/fr/manifestation/d...  fr-fr   Europe/Paris
# 2    https://www.ticketmaster.fr/fr/manifestation/m...  fr-fr   Europe/Paris
# 3    https://www.ticketmaster.fr/fr/manifestation/t...  fr-fr   Europe/Paris
# 4    https://www.ticketmaster.fr/fr/manifestation/p...  fr-fr   Europe/Paris
# ..                                                 ...    ...            ...
# 397  https://www.ticketmaster.de/event/kontra-k-%7C...  en-us  Europe/Berlin
# 398  https://www.ticketmaster.de/event/kontra-k-%7C...  en-us  Europe/Berlin
# 399  https://www.ticketmaster.de/event/playboi-cart...  en-us  Europe/Berlin
# 400  https://www.ticketmaster.de/event/playboi-cart...  en-us  Europe/Berlin
# 401  https://www.ticketmaster.de/event/post-malone-...  en-us  Europe/Berlin
#
#            date      time segment        genre     subgenre  \
# 0    2026-06-05  20:00:00   Music         Rock          Pop
# 1    2025-06-06  20:00:00    Film        Music        Music
# 2    2025-09-25  20:00:00    Film        Music        Music
# 3    2025-10-17  20:30:00   Music         Rock          Pop
# 4    2025-11-15  20:00:00   Music         Rock          Pop
# ..          ...       ...     ...          ...          ...
# 397  2025-11-26  20:00:00   Music  Hip-Hop/Rap  Hip-Hop/Rap
# 398  2025-11-27  20:00:00   Music  Hip-Hop/Rap  Hip-Hop/Rap
# 399  2025-12-31       NaN   Music  Hip-Hop/Rap  Hip-Hop/Rap
# 400  2025-12-31       NaN   Music  Hip-Hop/Rap  Hip-Hop/Rap
# 401  2025-08-18  18:00:00   Music  Hip-Hop/Rap  Hip-Hop/Rap
#
#                          venue      city  country  \
# 0    zenith toulouse metropole  Toulouse   France
# 1          cinema pathe wilson  Toulouse   France
# 2          cinema pathe wilson  Toulouse   France
# 3                  le metronum  Toulouse   France
# 4                    la cabane  Toulouse   France
# ..                         ...       ...      ...
# 397                 uber arena    Berlin  Germany
# 398                 uber arena    Berlin  Germany
# 399                 uber arena    Berlin  Germany
# 400                 uber arena    Berlin  Germany
# 401                        NaN    Berlin  Germany
#
#                               address  upcoming_events
# 0            11 avenue raymond badiou              111
# 1    3 pl. du président thomas wilson                2
# 2    3 pl. du président thomas wilson                2
# 3     2 rond point mme de mondonville                5
# 4           16 ter av. raymond badiou               31
# ..                                ...              ...
# 397                      uber-platz 1              112
# 398                      uber-platz 1              112
# 399                      uber-platz 1              112
# 400                      uber-platz 1              112
# 401                   straße am fez 4                8
#
# [402 rows x 15 columns]

# %% [markdown]
# *Checking events' genres:*

# %%
df_events['genre'].value_counts()
# Out:
# genre
# Rock                 171
# Hip-Hop/Rap           61
# Chanson Francaise     50
# Alternative           17
# Children's Music      13
# Pop                   13
# Classical             13
# Music                 12
# Dance/Electronic      12
# Metal                  9
# Undefined              8
# World                  7
# Jazz                   4
# Folk                   4
# R&B                    2
# Other                  2
# Religious              1
# Spectacular            1
# Theatre                1
# Family                 1
# Name: count, dtype: int64

# %%
#Group genre by city

grouped = df_events.groupby(['city', 'genre']).size().reset_index(name='count')

#Total events
city_totals = df_events['city'].value_counts().to_dict()

grouped['city_total'] = grouped['city'].map(city_totals)

# Calculate percentage per genre
grouped['percentage'] = (grouped['count'] / grouped['city_total']) * 100
grouped['percentage'] = grouped['percentage'].round(2)

grouped = grouped.sort_values(by=['city', 'genre'])

# %% [markdown]
# *We can see that in Berlin, Rock is the most popular genre, followed by Hip-Hop/Rap. In Toulouse, Chanson Française leads followed by Rock and Hip-Hop/Rap.*

# %%
display(grouped)
# Out:
#         city              genre  count  city_total  percentage
# 0     Berlin        Alternative     17         269        6.32
# 1     Berlin   Children's Music     11         269        4.09
# 2     Berlin          Classical     13         269        4.83
# 3     Berlin   Dance/Electronic     10         269        3.72
# 4     Berlin             Family      1         269        0.37
# 5     Berlin               Folk      4         269        1.49
# 6     Berlin        Hip-Hop/Rap     42         269       15.61
# 7     Berlin              Metal      2         269        0.74
# 8     Berlin              Other      2         269        0.74
# 9     Berlin                Pop     10         269        3.72
# 10    Berlin                R&B      1         269        0.37
# 11    Berlin               Rock    145         269       53.90
# 12    Berlin        Spectacular      1         269        0.37
# 13    Berlin            Theatre      1         269        0.37
# 14    Berlin          Undefined      3         269        1.12
# 15    Berlin              World      6         269        2.23
# 16  Toulouse  Chanson Francaise     50         133       37.59
# 17  Toulouse   Children's Music      2         133        1.50
# 18  Toulouse   Dance/Electronic      2         133        1.50
# 19  Toulouse        Hip-Hop/Rap     19         133       14.29
# 20  Toulouse               Jazz      4         133        3.01
# 21  Toulouse              Metal      7         133        5.26
# 22  Toulouse              Music     12         133        9.02
# 23  Toulouse                Pop      3         133        2.26
# 24  Toulouse                R&B      1         133        0.75
# 25  Toulouse          Religious      1         133        0.75
# 26  Toulouse               Rock     26         133       19.55
# 27  Toulouse          Undefined      5         133        3.76
# 28  Toulouse              World      1         133        0.75

# %%
pivot_genre_percent = grouped.pivot(index='genre', columns='city', values='percentage').fillna(0)

display(pivot_genre_percent)
# Out:
# city               Berlin  Toulouse
# genre
# Alternative          6.32      0.00
# Chanson Francaise    0.00     37.59
# Children's Music     4.09      1.50
# Classical            4.83      0.00
# Dance/Electronic     3.72      1.50
# Family               0.37      0.00
# Folk                 1.49      0.00
# Hip-Hop/Rap         15.61     14.29
# Jazz                 0.00      3.01
# Metal                0.74      5.26
# Music                0.00      9.02
# Other                0.74      0.00
# Pop                  3.72      2.26
# R&B                  0.37      0.75
# Religious            0.00      0.75
# Rock                53.90     19.55
# Spectacular          0.37      0.00
# Theatre              0.37      0.00
# Undefined            1.12      3.76
# World                2.23      0.75

# %% [markdown]
# *Checking events by month:*

# %%
df_events['date'] = pd.to_datetime(df_events['date'], errors='coerce')

df_events.head()
# Out:
#                                                 name  \
# 0              15 000 voix pour les legendes du rock
# 1  dirty dancing - l'ecran pop cinéma-karaoké:dir...
# 2  mamma mia ! - l'ecran pop cinéma-karaoké : mam...
# 3                                      the silencers
# 4                                              puggy
#
#                                          description  \
# 0  en tournée à partir de 2026vivez une expérienc...
# 1  tal ticket présente : l'ecran pop cinéma-karao...
# 2  tal ticket présente : l'ecran pop cinéma-karao...
# 3  the silencers en concert à toulouse le 17 octo...
# 4  pour des raisons indépendantes de notre volont...
#
#                                                  url locale      timezone  \
# 0  https://www.ticketmaster.fr/fr/manifestation/1...  fr-fr  Europe/Paris
# 1  https://www.ticketmaster.fr/fr/manifestation/d...  fr-fr  Europe/Paris
# 2  https://www.ticketmaster.fr/fr/manifestation/m...  fr-fr  Europe/Paris
# 3  https://www.ticketmaster.fr/fr/manifestation/t...  fr-fr  Europe/Paris
# 4  https://www.ticketmaster.fr/fr/manifestation/p...  fr-fr  Europe/Paris
#
#         date      time segment  genre subgenre                      venue  \
# 0 2026-06-05  20:00:00   Music   Rock      Pop  zenith toulouse metropole
# 1 2025-06-06  20:00:00    Film  Music    Music        cinema pathe wilson
# 2 2025-09-25  20:00:00    Film  Music    Music        cinema pathe wilson
# 3 2025-10-17  20:30:00   Music   Rock      Pop                le metronum
# 4 2025-11-15  20:00:00   Music   Rock      Pop                  la cabane
#
#        city country                           address  upcoming_events  \
# 0  Toulouse  France          11 avenue raymond badiou              111
# 1  Toulouse  France  3 pl. du président thomas wilson                2
# 2  Toulouse  France  3 pl. du président thomas wilson                2
# 3  Toulouse  France   2 rond point mme de mondonville                5
# 4  Toulouse  France         16 ter av. raymond badiou               31
#
#      month
# 0  2026-06
# 1  2025-06
# 2  2025-09
# 3  2025-10
# 4  2025-11

# %%
df_events['month'] = df_events['date'].dt.to_period('M').astype(str)

# %%
monthly_city_counts = df_events.groupby(['month', 'city']).size().reset_index(name='event_count')
pivot_eventcount = monthly_city_counts.pivot(index='month', columns='city', values='event_count').fillna(0)

pivot_eventcount.loc['Total'] = pivot_eventcount.sum()
pivot_eventcount = pivot_eventcount.astype(int)


display(pivot_eventcount)
# Out:
# city     Berlin  Toulouse
# month
# 2025-05      13         6
# 2025-06      43        14
# 2025-07      14         0
# 2025-08      30         0
# 2025-09      31         8
# 2025-10      44        21
# 2025-11      46        27
# 2025-12      18        11
# 2026-01       5        10
# 2026-02       6         3
# 2026-03       5        13
# 2026-04       2         5
# 2026-05       7         3
# 2026-06       3         3
# 2026-10       1         1
# 2026-11       0         4
# 2026-12       0         1
# 2027-01       0         2
# 2027-02       1         0
# 2027-09       0         1
# Total       269       133

# %%
monthly_counts = df_events.groupby(['city', 'month']).size().reset_index(name='count')

city_totals = df_events.groupby('city').size().reset_index(name='city_total')

monthly_counts = monthly_counts.merge(city_totals, on='city')

monthly_counts['percentage'] = (monthly_counts['count'] / monthly_counts['city_total']) * 100
monthly_counts['percentage'] = monthly_counts['percentage'].round(2)

pivot_events = monthly_counts.pivot(index='month', columns='city', values='percentage').fillna(0)

display(pivot_events)
# Out:
# city     Berlin  Toulouse
# month
# 2025-05    4.83      4.51
# 2025-06   15.99     10.53
# 2025-07    5.20      0.00
# 2025-08   11.15      0.00
# 2025-09   11.52      6.02
# 2025-10   16.36     15.79
# 2025-11   17.10     20.30
# 2025-12    6.69      8.27
# 2026-01    1.86      7.52
# 2026-02    2.23      2.26
# 2026-03    1.86      9.77
# 2026-04    0.74      3.76
# 2026-05    2.60      2.26
# 2026-06    1.12      2.26
# 2026-10    0.37      0.75
# 2026-11    0.00      3.01
# 2026-12    0.00      0.75
# 2027-01    0.00      1.50
# 2027-02    0.37      0.00
# 2027-09    0.00      0.75

# %%
import matplotlib.pyplot as plt

pivot_filtered = pivot_events.loc[~pivot_events.index.str.startswith('2027')]

# Plot grouped bar chart
pivot_filtered.plot(kind='bar', figsize=(12, 6), width=0.8)

plt.title("Monthly Event Count by City")
plt.xlabel("Month")
plt.ylabel("Number of Events")
plt.xticks(rotation=45)
plt.legend(title="City")
plt.tight_layout()
plt.show()
